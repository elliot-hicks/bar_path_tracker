# %%
# %load_ext autoreload
# %autoreload 2

from object_tracker import ObjectTracker
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = ObjectTracker()
bbox, start_bbox_centre, meters_per_pixel = t.get_starting_bbox(t.video_path, 0.43)
bar_path, output_video_path = t.track_bar_path(t.video_path, bbox, start_bbox_centre, meters_per_pixel, verbose=False)
stats, reps = t.get_set_summary(bar_path, 70)
t.show_video_with_stats(t.video_path, bar_path, stats, reps)
